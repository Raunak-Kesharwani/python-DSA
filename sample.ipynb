# %% [markdown]
# # Created this file "sample.ipynb" for experimenting with code snippets

# %%
prices = [7,1,5,3,6,4]

# %%
i = 1

# %%
prices[i+1:]
# Out:
# [5, 3, 6, 4]

# %%
a = b = 2
print(a,b)
# Out:
# 2 2

# %%
prices[:1]
# Out:
# [4, 6, 3, 5, 1, 7]

# %%
a = "A man, a plan, a canal: Panama"
a[::-1]
# Out:
# 'amanaP :lanac a ,nalp a ,nam A'

# %%
b = ""
for i in a :
    if i.isalnum() == True :
        b = b.join(i)

# %%
b
# Out:
# 'a'

# %%
a = "aa"
a.isalnum()
# Out:
# True

# %%
#how to remove space and special characters from a string
import re
import string

s = "Hello, World! 123 @#$"
# Keep only alphanumeric characters
cleaned_string = re.sub(r'[^a-zA-Z0-9]', '', s) 
print(cleaned_string)
# Output: "HelloWorld123"
# Out:
# HelloWorld123

# %%
s = "A man, a plan, a canal: Panama"
b = ""
for text in a :
    if text.isalnum() == 1 :
        b +=b.join(text)

# %%
b
# Out:
# 'AmanaplanacanalPanama'

# %%
text = "Hello @ World 123!"
clean_text = "".join(char for char in text if char.isalnum())
clean_text
# Out:
# 'HelloWorld123'

# %%
def isPalindrome(s: str) -> bool:
        s = "".join(text for text in s if s.isalnum() == True)
        if s[::-1] == s :
            return True
        else :
            return False

# %%
print(isPalindrome("race a car"))
# Out:
# True

# %%
t = "".join(text for text in s if s.isalnum() == True)

# %%
t
# Out:
# ''

# %%
t = [[-2, 0, 3, -5, 2, -1]]
sum(t[0][::1])
# Out:
# -3

# %%
out = []
out += ["null"]
out
# Out:
# ['null']

# %%
from typing import List
class NumArray:

    def __init__(self, nums: List[int]):
        if not nums:
            self.prefix = []
            return

        self.prefix = [0] * len(nums)
        self.prefix[0] = nums[0]

        for i in range(1, len(nums)):
            self.prefix[i] = self.prefix[i - 1] + nums[i]

    def sumRange(self, left: int, right: int) -> int:
        if left == 0:
            return self.prefix[right]
        return self.prefix[right] - self.prefix[left - 1]

# %%
obj = NumArray([-2, 0, 3, -5, 2, -1])
obj.sumRange(0, 2),obj.sumRange(2, 5),obj.sumRange(0, 5)
# Out:
# (1, -1, -3)

# %%
commands = ["NumArray", "sumRange", "sumRange", "sumRange"]
arguments = [[[-2, 0, 3, -5, 2, -1]], [0, 2], [2, 5], [0, 5]]

obj = None
output = []

for cmd, args in zip(commands, arguments):
    if cmd == "NumArray":
        obj = NumArray(*args)
        output.append(None)
        print(cmd , args)
    else:
        result = getattr(obj, cmd)(*args)
        output.append(result)
        print(cmd , args)
# Out:
# NumArray [[-2, 0, 3, -5, 2, -1]]
# sumRange [0, 2]
# sumRange [2, 5]
# sumRange [0, 5]

# %%
output
# Out:
# [None, 1, -1, -3]

# %%
def sam():
    for cmd , args in zip(commands , arguments):
        yield print(cmd , args)

# %%
a = [[-1,2,3]]
def sam(a):
    print(a)
sam(*a)
# Out:
# [-1, 2, 3]

# %%
class  sam :
    def __init__(self, nums):
        print(nums)

# %%
sam(*a)
# Out:
# [-1, 2, 3]

# %% [markdown]
# manadatory to attempt these questions
#
# 🔜 What I Recommend Next (Very Relevant)
#
# To fix OOP problem-solving permanently, do these next:
#
# Range Sum Query – Immutable ✅ (done)
#
# Design HashSet
#
# Design HashMap
#
# LRU Cache

# %%
def lengthOfLongestSubstring( s: str) -> int:
        length = 0 
        temp = ""
        for i in s :
            if i not in temp :
                temp += "".join(i)
                length += 1
            else:
                temp = temp.split(i)[1]
                length -= len(temp)
                temp += "".join(i)
        return length

# %%
lengthOfLongestSubstring("pwwkew")
# Out:
# 2

# %%
temp = "ppwwkew"

# %%
temp[1+1:]
# Out:
# 'wwkew'

# %%
nums = [1,2,3]
nums[:1],nums[1:]
# Out:
# ([1], [2, 3])

# %%
def sort_by_values(**kwargs):
    return dict(sorted(kwargs.items(), key=lambda item: item[1]))

data = {
    "apple": 50,
    "banana": 20,
    "cherry": 30
}

result = sort_by_values(**data)
print(result)
# Out:
# {'banana': 20, 'cherry': 30, 'apple': 50}
