# %%
import torch

# %%
device = torch.accelerator.current_accelerator().type

# %%
device
# Out:
# 'cuda'

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Work Fullstack\\Learn Agentic\\pytorch'
